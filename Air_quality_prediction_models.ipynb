# %% [markdown]
# <a href="https://colab.research.google.com/github/jenilvekariya123/PROJECTS/blob/main/Air_quality_prediction_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
# Method 3: Relative path (if file is in same directory as script)
df = pd.read_csv("air_pollution_data.csv")

# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import matplotlib.pyplot as plt

# Load your dataset (replace with your actual data loading)
# df = pd.read_csv("your_dataset.csv")

# Normalization (0 to 1)
num_cols = df.select_dtypes(include=['number']).columns
scaler = MinMaxScaler()
df_normalized = df.copy()  # Create a copy to preserve original data
df_normalized[num_cols] = scaler.fit_transform(df[num_cols])

# Visualization
plt.figure(figsize=(12, 6))
for col in num_cols[1:11]:  # Plot first 5 numeric columns for clarity
    plt.plot(df_normalized[col], label=col, alpha=0.7)
plt.title('Normalized Air Pollution Data (0-1 Scale)')
plt.xlabel('Index')
plt.ylabel('Normalized Value')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# Display first 5 rows of normalized data
print("\nFirst 5 rows of normalized data:")
print(df_normalized.head())

# Save normalized data to new CSV
df_normalized.to_csv('normalized_air_pollution_data.csv', index=False)
print("\nNormalized dataset saved as 'normalized_air_pollution_data.csv'")

# Return the normalized dataframe
df_normalized
# Out:
# First 5 rows of normalized data:
#         city        date  aqi        co        no       no2        o3  \
# 0  Ahmedabad  30-11-2020  1.0  0.015160  0.005199  0.048182  0.320427
# 1  Ahmedabad  01-12-2020  1.0  0.065889  0.016843  0.164520  0.001797
# 2  Ahmedabad  02-12-2020  1.0  0.071720  0.036132  0.147956  0.000418
# 3  Ahmedabad  03-12-2020  1.0  0.092711  0.090812  0.120048  0.000000
# 4  Ahmedabad  04-12-2020  1.0  0.088047  0.052254  0.176920  0.000049
#
#         so2     pm2_5      pm10       nh3
# 0  0.107366  0.029713  0.029462  0.023708
# 1  0.048630  0.054674  0.063392  0.077591
# 2  0.053468  0.060357  0.070845  0.079746
# 3  0.080417  0.068028  0.083000  0.103454
# 4  0.063167  0.072758  0.084503  0.114940
#
# Normalized dataset saved as 'normalized_air_pollution_data.csv'
#                 city        date   aqi        co        no       no2  \
# 0          Ahmedabad  30-11-2020  1.00  0.015160  0.005199  0.048182
# 1          Ahmedabad  01-12-2020  1.00  0.065889  0.016843  0.164520
# 2          Ahmedabad  02-12-2020  1.00  0.071720  0.036132  0.147956
# 3          Ahmedabad  03-12-2020  1.00  0.092711  0.090812  0.120048
# 4          Ahmedabad  04-12-2020  1.00  0.088047  0.052254  0.176920
# ...              ...         ...   ...       ...       ...       ...
# 23499  Visakhapatnam  21-05-2023  0.50  0.007872  0.000000  0.005340
# 23500  Visakhapatnam  22-05-2023  0.50  0.009038  0.000000  0.010439
# 23501  Visakhapatnam  23-05-2023  0.50  0.009475  0.000000  0.011978
# 23502  Visakhapatnam  24-05-2023  0.50  0.005539  0.000000  0.003168
# 23503  Visakhapatnam  25-05-2023  0.75  0.011079  0.000000  0.017167
#
#              o3       so2     pm2_5      pm10       nh3
# 0      0.320427  0.107366  0.029713  0.029462  0.023708
# 1      0.001797  0.048630  0.054674  0.063392  0.077591
# 2      0.000418  0.053468  0.060357  0.070845  0.079746
# 3      0.000000  0.080417  0.068028  0.083000  0.103454
# 4      0.000049  0.063167  0.072758  0.084503  0.114940
# ...         ...       ...       ...       ...       ...
# 23499  0.246486  0.008862  0.016809  0.019151  0.000227
# 23500  0.204224  0.011033  0.014376  0.017648  0.004934
# 23501  0.197184  0.011304  0.016119  0.019551  0.003403
# 23502  0.235902  0.004567  0.013468  0.019893  0.000000
# 23503  0.218303  0.023829  0.023540  0.025048  0.000567
#
# [23504 rows x 11 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter

# Use first 1000 points
sample_size = 1000
df_sample = df_normalized.head(sample_size).copy()

# Smoothing parameters
window_size = 21  # Larger window for cleaner smoothing
alpha = 0.15      # Stronger smoothing factor

# Calculate smoothed versions
df_sample['Smoothed_MA'] = df_sample['aqi'].rolling(window=window_size, center=True, min_periods=1).mean()
df_sample['Smoothed_EWM'] = df_sample['aqi'].ewm(alpha=alpha, adjust=False).mean()
df_sample['Reconstructed_SG'] = savgol_filter(df_sample['aqi'],
                                           window_length=window_size,
                                           polyorder=3)

# Create figure
plt.figure(figsize=(16, 8))

# Plot settings
plt.plot(df_sample['aqi'], color='#3498db', alpha=0.25, linewidth=1, label='Actual AQI')
plt.plot(df_sample['Smoothed_MA'], color='#e67e22', linewidth=2.5, label=f'Moving Average ({window_size}-day)')
plt.plot(df_sample['Smoothed_EWM'], color='#2ecc71', linewidth=2.5, label=f'Exponential (α={alpha})')
plt.plot(df_sample['Reconstructed_SG'], color='#e74c3c', linewidth=2, label='Savitzky-Golay')

# Formatting
plt.title(f'AQI Smoothing Comparison (First {sample_size} Samples)', fontsize=14, pad=15)
plt.xlabel('Time Index', fontsize=12)
plt.ylabel('Normalized AQI Value', fontsize=12)
plt.legend(fontsize=11, loc='upper right')
plt.grid(True, linestyle='--', alpha=0.3)


# Save sample data
df_sample.to_csv('aqi_smoothing_sample.csv', index=False)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Exclude non-numerical columns
numerical_cols = [col for col in df_normalized.columns
                 if col.lower() not in ['city', 'date'] and df_normalized[col].dtype in ['float64', 'int64']]

df_numerical = df_normalized[numerical_cols]

# Calculate correlation matrix
corr_matrix = df_numerical.corr()

# Visualize correlation matrix
plt.figure(figsize=(16, 12))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm',
            center=0, linewidths=0.5, annot_kws={"size": 8})
plt.title('Numerical Features Correlation Matrix (Excluding City/Date)', fontsize=16)
plt.tight_layout()
plt.show()

# %%
# Set threshold for high correlation
threshold = 0.85

# Find highly correlated features
high_corr = set()
for i in range(len(corr_matrix.columns)):
    for j in range(i):
        if abs(corr_matrix.iloc[i, j]) > threshold:
            colname = corr_matrix.columns[i]
            high_corr.add(colname)

print(f"Highly correlated numerical features (threshold={threshold}):")
print(high_corr)

# Create reduced dataset (keeping city and date)
cols_to_keep = [col for col in df_normalized.columns if col not in high_corr]
df_reduced_corr = df_normalized[cols_to_keep]

print("\nRemaining features after reduction:")
print(df_reduced_corr.columns.tolist())
# Out:
# Highly correlated numerical features (threshold=0.85):
# {'pm2_5', 'pm10'}
#
# Remaining features after reduction:
# ['city', 'date', 'aqi', 'co', 'no', 'no2', 'o3', 'so2', 'nh3']

# %%
# Save reduced dataset (including city and date if they existed)
df_reduced_corr.to_csv('crr_reduced_data.csv', index=False)
print("\nFinal reduced dataset saved as 'crr_reduced_data.csv'")
print(f"Original features: {len(df_normalized.columns)}")
print(f"Reduced features: {len(df_reduced_corr.columns)}")
# Out:
# Final reduced dataset saved as 'crr_reduced_data.csv'
# Original features: 11
# Reduced features: 9

# %% [markdown]
# # SVM **MODEL**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize

# Load the dataset
data = pd.read_csv('crr_reduced_data.csv')

# Convert AQI to binary classification (good/bad)
# Assuming: good (0) = AQI ≤ 100, bad (1) = AQI > 100
data['air_quality'] = np.where(data['aqi'] <= 0.5, 0, 1)  # Since normalized 0-1, 0.5 represents 100 AQI

# Features and target
X = data[['co', 'no', 'no2', 'o3', 'so2', 'nh3']]
y = data['air_quality']

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Initialize SVM classifier
svm_model = SVC(kernel='rbf', C=1.0, gamma='scale', probability=True, random_state=42)

# Train the model
svm_model.fit(X_train, y_train)
# Out:
# SVC(probability=True, random_state=42)

# %%
# Predictions
y_pred = svm_model.predict(X_test)
y_prob = svm_model.predict_proba(X_test)[:, 1]  # Probabilities for ROC curve

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

# Classification Report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[1490  505]
#  [ 293 4764]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.75      0.79      1995
#            1       0.90      0.94      0.92      5057
#
#     accuracy                           0.89      7052
#    macro avg       0.87      0.84      0.86      7052
# weighted avg       0.88      0.89      0.88      7052

# %%
plt.figure(figsize=(8, 6))
plt.imshow(conf_matrix, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix for SVM (Correlation Features)')
plt.colorbar()
tick_marks = np.arange(2)
plt.xticks(tick_marks, ['Good', 'Bad'], rotation=45)
plt.yticks(tick_marks, ['Good', 'Bad'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# Add text annotations
thresh = conf_matrix.max() / 2.
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        plt.text(j, i, format(conf_matrix[i, j], 'd'),
                 horizontalalignment="center",
                 color="white" if conf_matrix[i, j] > thresh else "black")

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import RocCurveDisplay, roc_curve, auc

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

# Create enhanced ROC curve plot
plt.figure(figsize=(10, 8))

# Plot ROC curve with more details
roc_display = RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc,
                             estimator_name='SVM Classifier')
roc_display.plot(ax=plt.gca(), color='darkorange', lw=3)

# Add important thresholds points
optimal_idx = np.argmax(tpr - fpr)
optimal_threshold = thresholds[optimal_idx]
plt.scatter(fpr[optimal_idx], tpr[optimal_idx], marker='o', color='red',
            label=f'Optimal Threshold (={optimal_threshold:.2f})')

# Add iso-f1 curves
x = np.linspace(0, 1, 100)
for f_score in [0.2, 0.4, 0.6, 0.8]:
    y = f_score * x / (2 * x - f_score)
    plt.plot(x[y >= 0], y[y >= 0], color='gray', alpha=0.2, linestyle='--')
    plt.annotate(f'f1={f_score:.1f}', xy=(0.9, y[45] + 0.02), alpha=0.5)

# Add diagonal and decorate
plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--', label='Random Classifier')
plt.xlim([-0.01, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (1 - Specificity)', fontsize=12)
plt.ylabel('True Positive Rate (Sensitivity)', fontsize=12)
plt.title('Enhanced ROC Curve Analysis\nSVM for Air Quality Prediction', fontsize=14, pad=20)
plt.legend(loc="lower right", fontsize=10)
plt.grid(True, alpha=0.3)

# Add performance metrics box
metrics_text = (f'AUC = {roc_auc:.3f}\n'
                f'Optimal Threshold = {optimal_threshold:.3f}\n'
                f'Sensitivity = {tpr[optimal_idx]:.2f}\n'
                f'Specificity = {1-fpr[optimal_idx]:.2f}')
plt.text(0.6, 0.2, metrics_text, bbox=dict(facecolor='white', alpha=0.8),
         fontsize=10)

plt.tight_layout()
plt.show()

# %%
# Get decision function distances
train_dist = svm_model.decision_function(X_train)
test_dist = svm_model.decision_function(X_test)

# Convert to "loss" (distance from margin)
train_loss = 1 - np.abs(train_dist)
test_loss = 1 - np.abs(test_dist)

# Plot training and testing "loss"
plt.figure(figsize=(8, 6))
plt.plot(np.sort(train_loss), label='Training')
plt.plot(np.sort(test_loss), label='Testing')
plt.title('Model Confidence (Distance from Decision Boundary)')
plt.xlabel('Samples')
plt.ylabel('1 - |Decision Function|')
plt.legend()
plt.show()

# %% [markdown]
# # LSTM Model For Correlation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, accuracy_score, confusion_matrix, classification_report
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.callbacks import EarlyStopping

# Load dataset
df = pd.read_csv('crr_reduced_data.csv')

# Select features and target
features = ['co', 'no', 'no2', 'o3', 'so2', 'nh3']
target = 'aqi'

# Normalize data
scaler = MinMaxScaler()
df_scaled = pd.DataFrame(
    scaler.fit_transform(df[features + [target]]),
    columns=features + [target]
)

# Create time-series sequences
def create_sequences(data, n_steps):
    X, y = [], []
    for i in range(len(data) - n_steps):
        X.append(data[i:i+n_steps, :-1])
        y.append(data[i+n_steps, -1])
    return np.array(X), np.array(y)

n_steps = 7
X, y = create_sequences(df_scaled.values, n_steps)

# Train-test split
train_size = int(0.8 * len(X))
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Build LSTM model
model = Sequential([
    LSTM(64, activation='relu', input_shape=(n_steps, len(features)), return_sequences=True),
    Dropout(0.2),
    LSTM(32, activation='relu'),
    Dropout(0.2),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# Early stopping
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train model
history = model.fit(
    X_train, y_train,
    epochs=10,
    batch_size=32,
    validation_split=0.2,
    callbacks=[early_stop],
    verbose=1
)

# Plot training history
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Training History')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error')
plt.legend()
plt.grid(True)
plt.show()

# Predictions
y_pred = model.predict(X_test)

# Inverse transform to original scale
y_test_full = np.zeros((len(y_test), len(features) + 1))
y_test_full[:, -1] = y_test
y_test_orig = scaler.inverse_transform(y_test_full)[:, -1]

y_pred_full = np.zeros((len(y_pred), len(features) + 1))
y_pred_full[:, -1] = y_pred.flatten()
y_pred_orig = scaler.inverse_transform(y_pred_full)[:, -1]

# Plot actual vs predicted AQI
plt.figure(figsize=(14, 6))
plt.plot(y_test_orig, label='Actual AQI', color='blue')
plt.plot(y_pred_orig, label='Predicted AQI', color='red', linestyle='--')
plt.title('Actual vs Predicted AQI Values')
plt.xlabel('Time Steps')
plt.ylabel('AQI')
plt.legend()
plt.grid(True)
plt.show()

# --- Regression Metrics ---
mse = mean_squared_error(y_test_orig, y_pred_orig)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_orig, y_pred_orig)
r2 = r2_score(y_test_orig, y_pred_orig)

print("\n--- Regression Metrics ---")
print(f"MAE: {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R² Score: {r2:.4f}")

# =============================================================================
# --- START: COMPLETE CLASSIFICATION ANALYSIS ---
# =============================================================================

# Define the threshold for what is considered 'Harmful' (using 0.5 for normalized AQI)
threshold = 0.5

# Convert continuous AQI values to binary classes: 0 for 'Safe', 1 for 'Harmful'
y_test_class = (y_test_orig > threshold).astype(int)
y_pred_class = (y_pred_orig > threshold).astype(int)

# --- 1. Overall Accuracy ---
accuracy = accuracy_score(y_test_class, y_pred_class)
print(f"\n--- Overall Classification Accuracy ---")
print(f"Accuracy (at normalized AQI threshold of {threshold}): {accuracy * 100:.2f}%")

# --- 2. Confusion Matrix ---
print("\n--- Confusion Matrix ---")
cm = confusion_matrix(y_test_class, y_pred_class)
plt.figure(figsize=(6, 5))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=['Predicted Safe', 'Predicted Harm'],
    yticklabels=['Actual Safe', 'Actual Harm']
)
plt.xlabel("Predicted Label")
plt.ylabel("Actual Label")
plt.title("Confusion Matrix")
plt.show()

# --- 3. Detailed Classification Report (Precision, Recall, F1-Score) ---
print("\n--- Detailed Classification Report ---")
# This report provides all the key ratios for both the 'Safe' and 'Harmful' classes.
report = classification_report(
    y_test_class,
    y_pred_class,
    target_names=[f'Safe (Normalized AQI <= {threshold})', f'Harmful (Normalized AQI > {threshold})']
)
print(report)

print("\n--- Interpretation of Key Ratios for 'Harmful' Class ---")
# Extracting recall for a clear explanation
# Ensure that both classes are present in y_test_class and y_pred_class before calculating recall
if cm.shape == (2, 2):
    recall = cm[1, 1] / (cm[1, 1] + cm[1, 0])
    print(f"Recall: The model successfully identified {recall:.2%} of all actually harmful days.")
    print(f"This means the model failed to issue a warning for {1-recall:.2%} of the harmful days (this is the False Negative rate).")
else:
    print("Recall for 'Harmful' class could not be calculated as only one class is present in the test data or predictions.")

# =============================================================================
# --- END: COMPLETE CLASSIFICATION ANALYSIS ---
# =============================================================================
# Out:
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - loss: 0.1972 - mae: 0.3541 - val_loss: 0.0468 - val_mae: 0.1638
# Epoch 2/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.0770 - mae: 0.2208 - val_loss: 0.0441 - val_mae: 0.1653
# Epoch 3/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0708 - mae: 0.2091 - val_loss: 0.0391 - val_mae: 0.1427
# Epoch 4/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0675 - mae: 0.2025 - val_loss: 0.0379 - val_mae: 0.1418
# Epoch 5/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - loss: 0.0658 - mae: 0.1991 - val_loss: 0.0394 - val_mae: 0.1387
# Epoch 6/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0625 - mae: 0.1923 - val_loss: 0.0365 - val_mae: 0.1316
# Epoch 7/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - loss: 0.0610 - mae: 0.1896 - val_loss: 0.0362 - val_mae: 0.1277
# Epoch 8/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.0595 - mae: 0.1886 - val_loss: 0.0368 - val_mae: 0.1327
# Epoch 9/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 0.0585 - mae: 0.1859 - val_loss: 0.0366 - val_mae: 0.1459
# Epoch 10/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0584 - mae: 0.1853 - val_loss: 0.0361 - val_mae: 0.1268
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step
# --- Regression Metrics ---
# MAE: 0.19
# RMSE: 0.25
# R² Score: 0.5029
#
# --- Overall Classification Accuracy ---
# Accuracy (at normalized AQI threshold of 0.5): 81.64%
#
# --- Confusion Matrix ---
# --- Detailed Classification Report ---
#                                 precision    recall  f1-score   support
#
#   Safe (Normalized AQI <= 0.5)       0.75      0.61      0.67      1456
# Harmful (Normalized AQI > 0.5)       0.84      0.91      0.87      3244
#
#                       accuracy                           0.82      4700
#                      macro avg       0.79      0.76      0.77      4700
#                   weighted avg       0.81      0.82      0.81      4700
#
#
# --- Interpretation of Key Ratios for 'Harmful' Class ---
# Recall: The model successfully identified 91.00% of all actually harmful days.
# This means the model failed to issue a warning for 9.00% of the harmful days (this is the False Negative rate).

# %% [markdown]
# # CNN-LSTM Model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, accuracy_score, confusion_matrix, classification_report
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, Conv1D, MaxPooling1D
from keras.callbacks import EarlyStopping

# Load dataset
df = pd.read_csv('crr_reduced_data.csv')

# Select features and target
features = ['co','no','no2','o3','so2','nh3']
target = 'aqi'

# Normalize data
scaler = MinMaxScaler()
df_scaled = pd.DataFrame(
    scaler.fit_transform(df[features + [target]]),
    columns=features + [target]
)

# Create time-series sequences
def create_sequences(data, n_steps):
    X, y = [], []
    for i in range(len(data) - n_steps):
        X.append(data[i:i+n_steps, :-1])
        y.append(data[i+n_steps, -1])
    return np.array(X), np.array(y)

n_steps = 7
X, y = create_sequences(df_scaled.values, n_steps)

# Train-test split
train_size = int(0.8 * len(X))
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Build CNN-LSTM model
model = Sequential([
    Conv1D(filters=64, kernel_size=2, activation='relu', input_shape=(n_steps, len(features))),
    MaxPooling1D(pool_size=2),
    LSTM(64, activation='relu', return_sequences=True),
    Dropout(0.2),
    LSTM(32, activation='relu'),
    Dropout(0.2),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# Early stopping
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train model
history = model.fit(
    X_train, y_train,
    epochs=10,
    batch_size=32,
    validation_split=0.2,
    callbacks=[early_stop],
    verbose=1
)

# Plot training history
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('CNN-LSTM Model Training History')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error')
plt.legend()
plt.grid(True)
plt.show()

# Predictions
y_pred = model.predict(X_test)

# Inverse transform to original scale
y_test_full = np.zeros((len(y_test), len(features) + 1))
y_test_full[:, -1] = y_test
y_test_orig = scaler.inverse_transform(y_test_full)[:, -1]

y_pred_full = np.zeros((len(y_pred), len(features) + 1))
y_pred_full[:, -1] = y_pred.flatten()
y_pred_orig = scaler.inverse_transform(y_pred_full)[:, -1]

# Plot actual vs predicted AQI
plt.figure(figsize=(14, 6))
plt.plot(y_test_orig, label='Actual AQI', color='blue')
plt.plot(y_pred_orig, label='Predicted AQI', color='red', linestyle='--')
plt.title('Actual vs Predicted AQI Values (CNN-LSTM)')
plt.xlabel('Time Steps')
plt.ylabel('AQI')
plt.legend()
plt.grid(True)
plt.show()

# --- Regression Metrics ---
mse = mean_squared_error(y_test_orig, y_pred_orig)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_orig, y_pred_orig)
r2 = r2_score(y_test_orig, y_pred_orig)

print("\n--- Regression Metrics ---")
print(f"MAE: {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R² Score: {r2:.4f}")

# --- Classification Analysis ---
threshold = 0.5  # AQI threshold for harmful
y_test_class = (y_test_orig > threshold).astype(int)
y_pred_class = (y_pred_orig > threshold).astype(int)

accuracy = accuracy_score(y_test_class, y_pred_class)
print(f"\n--- Classification Accuracy ---")
print(f"Accuracy: {accuracy * 100:.2f}%")

# Confusion matrix
cm = confusion_matrix(y_test_class, y_pred_class)
plt.figure(figsize=(6, 5))
sns.heatmap(
    cm, annot=True, fmt='d', cmap='Blues',
    xticklabels=['Predicted Safe', 'Predicted Harm'],
    yticklabels=['Actual Safe', 'Actual Harm']
)
plt.xlabel("Predicted Label")
plt.ylabel("Actual Label")
plt.title("Confusion Matrix for CNN-LSTM (Correlation Features)")
plt.show()

# Classification report
print("\n--- Detailed Classification Report ---")
print(classification_report(
    y_test_class, y_pred_class,
    target_names=[f'Safe (AQI <= {threshold})', f'Harmful (AQI > {threshold})']
))
# Out:
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 0.2090 - mae: 0.3656 - val_loss: 0.0513 - val_mae: 0.1693
# Epoch 2/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 0.0767 - mae: 0.2231 - val_loss: 0.0416 - val_mae: 0.1569
# Epoch 3/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0715 - mae: 0.2120 - val_loss: 0.0404 - val_mae: 0.1410
# Epoch 4/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0648 - mae: 0.1986 - val_loss: 0.0388 - val_mae: 0.1505
# Epoch 5/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0625 - mae: 0.1940 - val_loss: 0.0364 - val_mae: 0.1292
# Epoch 6/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0619 - mae: 0.1918 - val_loss: 0.0359 - val_mae: 0.1286
# Epoch 7/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0593 - mae: 0.1863 - val_loss: 0.0354 - val_mae: 0.1207
# Epoch 8/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0575 - mae: 0.1823 - val_loss: 0.0377 - val_mae: 0.1379
# Epoch 9/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0558 - mae: 0.1792 - val_loss: 0.0354 - val_mae: 0.1251
# Epoch 10/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0561 - mae: 0.1796 - val_loss: 0.0346 - val_mae: 0.1211
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# --- Regression Metrics ---
# MAE: 0.18
# RMSE: 0.24
# R² Score: 0.5460
#
# --- Classification Accuracy ---
# Accuracy: 82.13%
# --- Detailed Classification Report ---
#                      precision    recall  f1-score   support
#
#   Safe (AQI <= 0.5)       0.80      0.56      0.66      1456
# Harmful (AQI > 0.5)       0.83      0.94      0.88      3244
#
#            accuracy                           0.82      4700
#           macro avg       0.81      0.75      0.77      4700
#        weighted avg       0.82      0.82      0.81      4700

# %% [markdown]
# # Transformer Model for Correlation

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import (
    mean_squared_error, mean_absolute_error, r2_score,
    accuracy_score, precision_score, recall_score,
    confusion_matrix, classification_report
)

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks

# ---------------- Config ----------------
CSV_PATH   = "crr_reduced_data.csv"
FEATURES   = ['co', 'no', 'no2', 'o3', 'so2','nh3']
TARGET     = 'aqi'
N_STEPS    = 7
THRESHOLD  = 0.5
EPOCHS     = 20
BATCH_SIZE = 32
VAL_SPLIT  = 0.2
PATIENCE   = 10

# -------------- Data load & scale --------------
df = pd.read_csv(CSV_PATH)

scaler = MinMaxScaler()
df_scaled = pd.DataFrame(
    scaler.fit_transform(df[FEATURES + [TARGET]]),
    columns=FEATURES + [TARGET]
)

def create_sequences(data, n_steps):
    X, y = [], []
    for i in range(len(data) - n_steps):
        X.append(data[i:i+n_steps, :-1])
        y.append(data[i+n_steps, -1])
    return np.array(X), np.array(y)

X, y = create_sequences(df_scaled.values, N_STEPS)

# Train-test split (time-ordered, like your code)
train_size = int(0.8 * len(X))
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

n_features = X.shape[2]
d_model    = 64
num_heads  = 4
d_ff       = 128
dropout    = 0.1
num_layers = 2

# -------------- Positional embedding --------------
class PositionalEmbedding(layers.Layer):
    def __init__(self, maxlen, d_model):
        super().__init__()
        self.pos_emb = self.add_weight(
            name="pos_emb", shape=(1, maxlen, d_model),
            initializer="random_normal", trainable=True
        )
    def call(self, x):
        # x: (batch, time, d_model)
        return x + self.pos_emb[:, :tf.shape(x)[1], :]

# -------------- Transformer block --------------
def transformer_block(x, d_model, num_heads, d_ff, dropout):
    # Multi-Head Self Attention
    attn_out = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model//num_heads)(x, x)
    x = layers.Add()([x, layers.Dropout(dropout)(attn_out)])
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    # Feed Forward
    ffn = models.Sequential([
        layers.Dense(d_ff, activation="gelu"),
        layers.Dense(d_model),
    ])
    ffn_out = ffn(x)
    x = layers.Add()([x, layers.Dropout(dropout)(ffn_out)])
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    return x

# -------------- Build model --------------
inp = layers.Input(shape=(N_STEPS, n_features))
# Project per-timestep feature vector to d_model
x = layers.Dense(d_model)(inp)
# Add learnable positional embedding
x = PositionalEmbedding(N_STEPS, d_model)(x)
# Stack Transformer encoder layers
for _ in range(num_layers):
    x = transformer_block(x, d_model, num_heads, d_ff, dropout)
# Pool over time
x = layers.GlobalAveragePooling1D()(x)
x = layers.Dropout(dropout)(x)
out = layers.Dense(1)(x)  # regression to normalized AQI

model = models.Model(inp, out, name="AQI_Transformer")
model.compile(optimizer="adam", loss="mse", metrics=["mae"])
model.summary()

early_stop = callbacks.EarlyStopping(monitor="val_loss", patience=PATIENCE, restore_best_weights=True)

# -------------- Train --------------
history = model.fit(
    X_train, y_train,
    epochs=10,
    batch_size=BATCH_SIZE,
    validation_split=VAL_SPLIT,
    callbacks=[early_stop],
    verbose=1
)

# -------------- Plot: training history (loss) --------------
plt.figure(figsize=(10, 5))
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.xlabel("Epochs"); plt.ylabel("MSE"); plt.title("Transformer Training History (Loss)")
plt.legend(); plt.grid(True)
plt.show()

# -------------- Predict & inverse-transform to original scale --------------
y_pred = model.predict(X_test).flatten()

# prepare arrays for inverse scaling (target is last column)
def inverse_target_only(scaled_target):
    z = np.zeros((len(scaled_target), len(FEATURES) + 1))
    z[:, -1] = scaled_target
    return scaler.inverse_transform(z)[:, -1]

y_test_orig = inverse_target_only(y_test)
y_pred_orig = inverse_target_only(y_pred)

# -------------- Regression metrics --------------
mse  = mean_squared_error(y_test_orig, y_pred_orig)
rmse = np.sqrt(mse)
mae  = mean_absolute_error(y_test_orig, y_pred_orig)
r2   = r2_score(y_test_orig, y_pred_orig)

print("\n--- Transformer Regression Metrics ---")
print(f"MAE:  {mae:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"R^2:  {r2:.4f}")

# -------------- Classification metrics (threshold on ORIGINAL scale) --------------
y_test_cls = (y_test_orig > THRESHOLD).astype(int)
y_pred_cls = (y_pred_orig > THRESHOLD).astype(int)

acc  = accuracy_score(y_test_cls, y_pred_cls)
prec = precision_score(y_test_cls, y_pred_cls, zero_division=0)
rec  = recall_score(y_test_cls, y_pred_cls, zero_division=0)

print("\n--- Transformer Classification Metrics ---")
print(f"Accuracy:  {acc*100:.2f}%")
print(f"Precision: {prec:.4f}")
print(f"Recall:    {rec:.4f}")

# Confusion matrix
cm = confusion_matrix(y_test_cls, y_pred_cls)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=["Pred Safe", "Pred Harm"],
            yticklabels=["Actual Safe", "Actual Harm"])
plt.xlabel("Predicted"); plt.ylabel("Actual"); plt.title("Confusion Matrix for Transformer (Correlation Features)")
plt.show()

# -------------- Cumulative Gain Curve --------------
# Use predicted AQI as a risk score (higher AQI => more likely 'harmful')
order = np.argsort(-y_pred_orig)  # descending by predicted AQI
y_true_sorted = y_test_cls[order]
cum_positives = np.cumsum(y_true_sorted == 1)
total_positives = (y_test_cls == 1).sum()
n = len(y_true_sorted)
perc_samples = np.arange(1, n+1) / n
gain = cum_positives / max(total_positives, 1)

plt.figure(figsize=(8, 6))
plt.plot(perc_samples, gain, label="Model")
plt.plot(perc_samples, perc_samples, label="Baseline")
plt.xlabel("Percentage of Samples")
plt.ylabel("Percentage of Positives Captured")
plt.title("Cumulative Gain Curve (Transformer)")
plt.legend(); plt.grid(True)
plt.show()

# -------------- Actual vs Predicted plot --------------
plt.figure(figsize=(12, 5))
plt.plot(y_test_orig, label="Actual AQI")
plt.plot(y_pred_orig, label="Predicted AQI", linestyle="--")
plt.xlabel("Time Steps"); plt.ylabel("AQI")
plt.title("Actual vs Predicted AQI (Transformer)")
plt.legend(); plt.grid(True)
plt.show()
# Out:
# Model: "AQI_Transformer"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 7, 6)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 7, 64)     │        448 │ input_layer_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ positional_embeddi… │ (None, 7, 64)     │        448 │ dense_2[0][0]     │
# │ (PositionalEmbeddi… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 7, 64)     │     16,640 │ positional_embed… │
# │ (MultiHeadAttentio… │                   │            │ positional_embed… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 7, 64)     │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 7, 64)     │          0 │ positional_embed… │
# │                     │                   │            │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 7, 64)     │        128 │ add[0][0]         │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_2        │ (None, 7, 64)     │     16,576 │ layer_normalizat… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 7, 64)     │          0 │ sequential_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 7, 64)     │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 7, 64)     │        128 │ add_1[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 7, 64)     │     16,640 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 7, 64)     │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 7, 64)     │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 7, 64)     │        128 │ add_2[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_3        │ (None, 7, 64)     │     16,576 │ layer_normalizat… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 7, 64)     │          0 │ sequential_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 7, 64)     │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_9[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 7, 64)     │        128 │ add_3[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ layer_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 64)        │          0 │ global_average_p… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 1)         │         65 │ dropout_10[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 67,905 (265.25 KB)
#  Trainable params: 67,905 (265.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - loss: 0.1777 - mae: 0.3110 - val_loss: 0.0366 - val_mae: 0.1325
# Epoch 2/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 0.0673 - mae: 0.1996 - val_loss: 0.0352 - val_mae: 0.1205
# Epoch 3/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 19s 26ms/step - loss: 0.0591 - mae: 0.1839 - val_loss: 0.0343 - val_mae: 0.1139
# Epoch 4/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 21s 27ms/step - loss: 0.0565 - mae: 0.1779 - val_loss: 0.0352 - val_mae: 0.1145
# Epoch 5/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - loss: 0.0559 - mae: 0.1770 - val_loss: 0.0389 - val_mae: 0.1219
# Epoch 6/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 21s 25ms/step - loss: 0.0539 - mae: 0.1727 - val_loss: 0.0334 - val_mae: 0.1152
# Epoch 7/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 21s 27ms/step - loss: 0.0545 - mae: 0.1747 - val_loss: 0.0322 - val_mae: 0.1154
# Epoch 8/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 19s 25ms/step - loss: 0.0527 - mae: 0.1708 - val_loss: 0.0386 - val_mae: 0.1335
# Epoch 9/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 21s 26ms/step - loss: 0.0537 - mae: 0.1723 - val_loss: 0.0361 - val_mae: 0.1243
# Epoch 10/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - loss: 0.0531 - mae: 0.1702 - val_loss: 0.0337 - val_mae: 0.1089
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step
#
# --- Transformer Regression Metrics ---
# MAE:  0.1888
# RMSE: 0.2552
# R^2:  0.4988
#
# --- Transformer Classification Metrics ---
# Accuracy:  82.57%
# Precision: 0.8716
# Recall:    0.8767

# %% [markdown]
# # Ranking Based **Featured**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor

# Remove non-numeric columns (assuming they exist)
if 'city' in df_normalized.columns:
    df_normalized = df_normalized.drop('city', axis=1)
if 'date' in df_normalized.columns:
    df_normalized = df_normalized.drop('date', axis=1)

# Calculate correlation matrix with AQI
corr_matrix = df_normalized.corr()
aqi_correlation = corr_matrix['aqi'].sort_values(ascending=False)

# Plot correlation with AQI
plt.figure(figsize=(8, 10))
aqi_correlation.drop('aqi').plot(kind='barh', color='teal')
plt.title('Correlation with AQI', fontsize=14)
plt.xlabel('Correlation Coefficient', fontsize=12)
plt.ylabel('Features', fontsize=12)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# Feature importance using Random Forest
X = df_normalized.drop('aqi', axis=1)
y = df_normalized['aqi']

model = RandomForestRegressor(random_state=42, n_estimators=100)
model.fit(X, y)

# Get feature importances
importances = model.feature_importances_
feature_importance = pd.DataFrame({
    'Feature': X.columns,
    'Importance': importances
}).sort_values('Importance', ascending=False)

# Plot feature importance (more visible bars + x-axis limit)
plt.figure(figsize=(10, 6))
plt.barh(
    feature_importance['Feature'],
    feature_importance['Importance'],
    color='darkorange',
    height=0.6   # thicker bars for better visibility
)
plt.title('Feature Importance Ranking', fontsize=14)
plt.xlabel('Relative Importance', fontsize=12)
plt.ylabel('Features', fontsize=12)
plt.xlim(0, 0.025)   # set max value of x-axis to 0.3
plt.gca().invert_yaxis()
plt.grid(True, alpha=0.3, axis='x')
plt.tight_layout()
plt.show()


print("Feature Importance Ranking:")
print(feature_importance)
# Out:
# Feature Importance Ranking:
#   Feature  Importance
# 5   pm2_5    0.967586
# 6    pm10    0.011097
# 7     nh3    0.004581
# 3      o3    0.004138
# 4     so2    0.004129
# 2     no2    0.003991
# 0      co    0.003587
# 1      no    0.000890

# %%
# Select top 3 most important features (excluding target)
important_features = feature_importance.head(5)['Feature'].tolist()

# Make sure aqi is included
if 'aqi' not in important_features:
    important_features.append('aqi')

# Create reduced dataset
df_reduced_pr = df_normalized[important_features].copy()

print("\nSelected Features:", important_features)
print("Reduced dataset shape:", df_reduced_pr.shape)
print("\nFirst 5 rows of reduced dataset:")
print(df_reduced_pr.head())

df_reduced_pr.to_csv('pr_reduced_data.csv', index=False)
# Out:
# Selected Features: ['pm2_5', 'pm10', 'nh3', 'o3', 'so2', 'aqi']
# Reduced dataset shape: (23504, 6)
#
# First 5 rows of reduced dataset:
#       pm2_5      pm10       nh3        o3       so2  aqi
# 0  0.029713  0.029462  0.023708  0.320427  0.107366  1.0
# 1  0.054674  0.063392  0.077591  0.001797  0.048630  1.0
# 2  0.060357  0.070845  0.079746  0.000418  0.053468  1.0
# 3  0.068028  0.083000  0.103454  0.000000  0.080417  1.0
# 4  0.072758  0.084503  0.114940  0.000049  0.063167  1.0

# %% [markdown]
# # **SVM**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize

# Load the dataset
data = pd.read_csv('pr_reduced_data.csv')

# Convert AQI to binary classification (good/bad)
# Assuming: good (0) = AQI ≤ 100, bad (1) = AQI > 100
data['air_quality'] = np.where(data['aqi'] <= 0.5, 0, 1)  # Since normalized 0-1, 0.5 represents 100 AQI

# Features and target
X = data[['pm2_5', 'pm10', 'nh3', 'o3', 'so2']]
y = data['air_quality']

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)


# Initialize SVM classifier
svm_model = SVC(kernel='rbf', C=1.0, gamma='scale', probability=True, random_state=42)

# Train the model
svm_model.fit(X_train, y_train)

# Predictions
y_pred = svm_model.predict(X_test)
y_prob = svm_model.predict_proba(X_test)[:, 1]  # Probabilities for ROC curve

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

# Classification Report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

plt.figure(figsize=(8, 6))
plt.imshow(conf_matrix, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix for SVM (Ranking Based Feature)')
plt.colorbar()
tick_marks = np.arange(2)
plt.xticks(tick_marks, ['Good', 'Bad'], rotation=45)
plt.yticks(tick_marks, ['Good', 'Bad'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# Add text annotations
thresh = conf_matrix.max() / 2.
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        plt.text(j, i, format(conf_matrix[i, j], 'd'),
                 horizontalalignment="center",
                 color="white" if conf_matrix[i, j] > thresh else "black")

plt.tight_layout()
plt.show()
# Out:
# Confusion Matrix:
# [[1743  252]
#  [ 159 4898]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.87      0.89      1995
#            1       0.95      0.97      0.96      5057
#
#     accuracy                           0.94      7052
#    macro avg       0.93      0.92      0.93      7052
# weighted avg       0.94      0.94      0.94      7052

# %%
from sklearn.metrics import RocCurveDisplay, roc_curve, auc

# Create enhanced ROC curve plot
plt.figure(figsize=(10, 8))

# Plot ROC curve with more details
roc_display = RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc,
                             estimator_name='SVM Classifier')
roc_display.plot(ax=plt.gca(), color='darkorange', lw=3)

# Add important thresholds points
optimal_idx = np.argmax(tpr-fpr)
optimal_threshold = thresholds[optimal_idx]
plt.scatter(fpr[optimal_idx], tpr[optimal_idx], marker='o', color='red',
            label=f'Optimal Threshold (={optimal_threshold:.2f})')

# Add iso-f1 curves
x = np.linspace(0, 1, 100)
for f_score in [0.2, 0.4, 0.6, 0.8]:
    y = f_score * x / (2 * x - f_score)
    plt.plot(x[y >= 0], y[y >= 0], color='gray', alpha=0.2, linestyle='--')
    plt.annotate(f'f1={f_score:.1f}', xy=(0.9, y[45] + 0.02), alpha=0.5)

# Add diagonal and decorate
plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--', label='Random Classifier')
plt.xlim([-0.01, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (1 - Specificity)', fontsize=12)
plt.ylabel('True Positive Rate (Sensitivity)', fontsize=12)
plt.title('Enhanced ROC Curve Analysis\nSVM for Air Quality Prediction', fontsize=14, pad=20)
plt.legend(loc="lower right", fontsize=10)
plt.grid(True, alpha=0.3)

# Add performance metrics box
metrics_text = (f'AUC = {roc_auc:.3f}\n'
                f'Optimal Threshold = {optimal_threshold:.3f}\n'
                f'Sensitivity = {tpr[optimal_idx]:.2f}\n'
                f'Specificity = {1-fpr[optimal_idx]:.2f}')
plt.text(0.6, 0.2, metrics_text, bbox=dict(facecolor='white', alpha=0.8),
         fontsize=10)

plt.tight_layout()
plt.show()

# %% [markdown]
# # LSTM Model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, accuracy_score, confusion_matrix, classification_report
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.callbacks import EarlyStopping

# Load dataset
df = pd.read_csv('pr_reduced_data.csv')

# Select features and target
features = ['pm2_5', 'pm10', 'nh3', 'o3', 'so2']
target = 'aqi'

# Normalize data
scaler = MinMaxScaler()
df_scaled = pd.DataFrame(
    scaler.fit_transform(df[features + [target]]),
    columns=features + [target]
)

# Create time-series sequences
def create_sequences(data, n_steps):
    X, y = [], []
    for i in range(len(data) - n_steps):
        X.append(data[i:i+n_steps, :-1])
        y.append(data[i+n_steps, -1])
    return np.array(X), np.array(y)

n_steps = 7
X, y = create_sequences(df_scaled.values, n_steps)

# Train-test split
train_size = int(0.8 * len(X))
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Build LSTM model
model = Sequential([
    LSTM(64, activation='relu', input_shape=(n_steps, len(features)), return_sequences=True),
    Dropout(0.2),
    LSTM(32, activation='relu'),
    Dropout(0.2),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# Early stopping
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train model
history = model.fit(
    X_train, y_train,
    epochs=10,
    batch_size=32,
    validation_split=0.2,
    callbacks=[early_stop],
    verbose=1
)

# Plot training history
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Training History')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error')
plt.legend()
plt.grid(True)
plt.show()

# Predictions
y_pred = model.predict(X_test)

# Inverse transform to original scale
y_test_full = np.zeros((len(y_test), len(features) + 1))
y_test_full[:, -1] = y_test
y_test_orig = scaler.inverse_transform(y_test_full)[:, -1]

y_pred_full = np.zeros((len(y_pred), len(features) + 1))
y_pred_full[:, -1] = y_pred.flatten()
y_pred_orig = scaler.inverse_transform(y_pred_full)[:, -1]

# Plot actual vs predicted AQI
plt.figure(figsize=(14, 6))
plt.plot(y_test_orig, label='Actual AQI', color='blue')
plt.plot(y_pred_orig, label='Predicted AQI', color='red', linestyle='--')
plt.title('Actual vs Predicted AQI Values')
plt.xlabel('Time Steps')
plt.ylabel('AQI')
plt.legend()
plt.grid(True)
plt.show()

# --- Regression Metrics ---
mse = mean_squared_error(y_test_orig, y_pred_orig)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_orig, y_pred_orig)
r2 = r2_score(y_test_orig, y_pred_orig)

print("\n--- Regression Metrics ---")
print(f"MAE: {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R² Score: {r2:.4f}")

# Define the threshold for what is considered 'Harmful' (using 0.5 for normalized AQI)
threshold = 0.5

# Convert continuous AQI values to binary classes: 0 for 'Safe', 1 for 'Harmful'
y_test_class = (y_test_orig > threshold).astype(int)
y_pred_class = (y_pred_orig > threshold).astype(int)

# --- 1. Overall Accuracy ---
accuracy = accuracy_score(y_test_class, y_pred_class)
print(f"\n--- Overall Classification Accuracy ---")
print(f"Accuracy (at normalized AQI threshold of {threshold}): {accuracy * 100:.2f}%")

# --- 2. Confusion Matrix ---
print("\n--- Confusion Matrix ---")
cm = confusion_matrix(y_test_class, y_pred_class)
plt.figure(figsize=(6, 5))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=['Predicted Safe', 'Predicted Harm'],
    yticklabels=['Actual Safe', 'Actual Harm']
)
plt.xlabel("Predicted Label")
plt.ylabel("Actual Label")
plt.title("Confusion Matrix")
plt.show()

# --- 3. Detailed Classification Report (Precision, Recall, F1-Score) ---
print("\n--- Detailed Classification Report ---")
# This report provides all the key ratios for both the 'Safe' and 'Harmful' classes.
report = classification_report(
    y_test_class,
    y_pred_class,
    target_names=[f'Safe (Normalized AQI <= {threshold})', f'Harmful (Normalized AQI > {threshold})']
)
print(report)

print("\n--- Interpretation of Key Ratios for 'Harmful' Class ---")
# Extracting recall for a clear explanation
# Ensure that both classes are present in y_test_class and y_pred_class before calculating recall
if cm.shape == (2, 2):
    recall = cm[1, 1] / (cm[1, 1] + cm[1, 0])
    print(f"Recall: The model successfully identified {recall:.2%} of all actually harmful days.")
    print(f"This means the model failed to issue a warning for {1-recall:.2%} of the harmful days (this is the False Negative rate).")
else:
    print("Recall for 'Harmful' class could not be calculated as only one class is present in the test data or predictions.")
# Out:
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 18s 25ms/step - loss: 0.2040 - mae: 0.3597 - val_loss: 0.0655 - val_mae: 0.2037
# Epoch 2/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - loss: 0.0776 - mae: 0.2286 - val_loss: 0.0430 - val_mae: 0.1513
# Epoch 3/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 0.0684 - mae: 0.2078 - val_loss: 0.0410 - val_mae: 0.1496
# Epoch 4/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 18s 20ms/step - loss: 0.0627 - mae: 0.1956 - val_loss: 0.0404 - val_mae: 0.1484
# Epoch 5/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 0.0604 - mae: 0.1925 - val_loss: 0.0406 - val_mae: 0.1560
# Epoch 6/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0601 - mae: 0.1931 - val_loss: 0.0396 - val_mae: 0.1431
# Epoch 7/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0595 - mae: 0.1907 - val_loss: 0.0377 - val_mae: 0.1411
# Epoch 8/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.0574 - mae: 0.1855 - val_loss: 0.0361 - val_mae: 0.1322
# Epoch 9/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0558 - mae: 0.1816 - val_loss: 0.0361 - val_mae: 0.1241
# Epoch 10/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 0.0533 - mae: 0.1770 - val_loss: 0.0351 - val_mae: 0.1275
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step
# --- Regression Metrics ---
# MAE: 0.17
# RMSE: 0.23
# R² Score: 0.5991
#
# --- Overall Classification Accuracy ---
# Accuracy (at normalized AQI threshold of 0.5): 83.57%
#
# --- Confusion Matrix ---
# --- Detailed Classification Report ---
#                                 precision    recall  f1-score   support
#
#   Safe (Normalized AQI <= 0.5)       0.79      0.64      0.71      1456
# Harmful (Normalized AQI > 0.5)       0.85      0.92      0.89      3244
#
#                       accuracy                           0.84      4700
#                      macro avg       0.82      0.78      0.80      4700
#                   weighted avg       0.83      0.84      0.83      4700
#
#
# --- Interpretation of Key Ratios for 'Harmful' Class ---
# Recall: The model successfully identified 92.23% of all actually harmful days.
# This means the model failed to issue a warning for 7.77% of the harmful days (this is the False Negative rate).

# %% [markdown]
# # CNN-LSTM Models

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, accuracy_score, confusion_matrix, classification_report
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, Conv1D, MaxPooling1D
from keras.callbacks import EarlyStopping

# Load dataset
df = pd.read_csv('pr_reduced_data.csv')

# Select features and target
features = ['pm2_5', 'pm10', 'nh3', 'o3', 'so2']
target = 'aqi'

# Normalize data
scaler = MinMaxScaler()
df_scaled = pd.DataFrame(
    scaler.fit_transform(df[features + [target]]),
    columns=features + [target]
)

# Create time-series sequences
def create_sequences(data, n_steps):
    X, y = [], []
    for i in range(len(data) - n_steps):
        X.append(data[i:i+n_steps, :-1])
        y.append(data[i+n_steps, -1])
    return np.array(X), np.array(y)

n_steps = 7
X, y = create_sequences(df_scaled.values, n_steps)

# Train-test split
train_size = int(0.8 * len(X))
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Build CNN-LSTM model
model = Sequential([
    Conv1D(filters=64, kernel_size=2, activation='relu', input_shape=(n_steps, len(features))),
    MaxPooling1D(pool_size=2),
    LSTM(64, activation='relu', return_sequences=True),
    Dropout(0.2),
    LSTM(32, activation='relu'),
    Dropout(0.2),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# Early stopping
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train model
history = model.fit(
    X_train, y_train,
    epochs=10,
    batch_size=32,
    validation_split=0.2,
    callbacks=[early_stop],
    verbose=1
)

# Plot training history
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('CNN-LSTM Model Training History')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error')
plt.legend()
plt.grid(True)
plt.show()

# Predictions
y_pred = model.predict(X_test)

# Inverse transform to original scale
y_test_full = np.zeros((len(y_test), len(features) + 1))
y_test_full[:, -1] = y_test
y_test_orig = scaler.inverse_transform(y_test_full)[:, -1]

y_pred_full = np.zeros((len(y_pred), len(features) + 1))
y_pred_full[:, -1] = y_pred.flatten()
y_pred_orig = scaler.inverse_transform(y_pred_full)[:, -1]

# Plot actual vs predicted AQI
plt.figure(figsize=(14, 6))
plt.plot(y_test_orig, label='Actual AQI', color='blue')
plt.plot(y_pred_orig, label='Predicted AQI', color='red', linestyle='--')
plt.title('Actual vs Predicted AQI Values (CNN-LSTM)')
plt.xlabel('Time Steps')
plt.ylabel('AQI')
plt.legend()
plt.grid(True)
plt.show()

# --- Regression Metrics ---
mse = mean_squared_error(y_test_orig, y_pred_orig)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_orig, y_pred_orig)
r2 = r2_score(y_test_orig, y_pred_orig)

print("\n--- Regression Metrics ---")
print(f"MAE: {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R² Score: {r2:.4f}")

# --- Classification Analysis ---
threshold = 0.5  # AQI threshold for harmful
y_test_class = (y_test_orig > threshold).astype(int)
y_pred_class = (y_pred_orig > threshold).astype(int)

accuracy = accuracy_score(y_test_class, y_pred_class)
print(f"\n--- Classification Accuracy ---")
print(f"Accuracy: {accuracy * 100:.2f}%")

# Confusion matrix
cm = confusion_matrix(y_test_class, y_pred_class)
plt.figure(figsize=(6, 5))
sns.heatmap(
    cm, annot=True, fmt='d', cmap='Blues',
    xticklabels=['Predicted Safe', 'Predicted Harm'],
    yticklabels=['Actual Safe', 'Actual Harm']
)
plt.xlabel("Predicted Label")
plt.ylabel("Actual Label")
plt.title("Confusion Matrix for CNN-LSTM (Ranking Based Feature)")
plt.show()

# Classification report
print("\n--- Detailed Classification Report ---")
print(classification_report(
    y_test_class, y_pred_class,
    target_names=[f'Safe (AQI <= {threshold})', f'Harmful (AQI > {threshold})']
))
# Out:
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 0.2031 - mae: 0.3607 - val_loss: 0.0496 - val_mae: 0.1684
# Epoch 2/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0718 - mae: 0.2158 - val_loss: 0.0436 - val_mae: 0.1583
# Epoch 3/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.0650 - mae: 0.2023 - val_loss: 0.0401 - val_mae: 0.1403
# Epoch 4/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0622 - mae: 0.1964 - val_loss: 0.0366 - val_mae: 0.1304
# Epoch 5/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0563 - mae: 0.1830 - val_loss: 0.0349 - val_mae: 0.1361
# Epoch 6/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.0529 - mae: 0.1756 - val_loss: 0.0359 - val_mae: 0.1422
# Epoch 7/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0492 - mae: 0.1679 - val_loss: 0.0329 - val_mae: 0.1301
# Epoch 8/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0479 - mae: 0.1645 - val_loss: 0.0334 - val_mae: 0.1293
# Epoch 9/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.0479 - mae: 0.1646 - val_loss: 0.0315 - val_mae: 0.1241
# Epoch 10/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0476 - mae: 0.1639 - val_loss: 0.0306 - val_mae: 0.1174
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# --- Regression Metrics ---
# MAE: 0.16
# RMSE: 0.22
# R² Score: 0.6341
#
# --- Classification Accuracy ---
# Accuracy: 83.81%
# --- Detailed Classification Report ---
#                      precision    recall  f1-score   support
#
#   Safe (AQI <= 0.5)       0.84      0.59      0.69      1456
# Harmful (AQI > 0.5)       0.84      0.95      0.89      3244
#
#            accuracy                           0.84      4700
#           macro avg       0.84      0.77      0.79      4700
#        weighted avg       0.84      0.84      0.83      4700

# %% [markdown]
# # Transformer Model for Importance ranking

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import (
    mean_squared_error, mean_absolute_error, r2_score,
    accuracy_score, precision_score, recall_score,
    confusion_matrix, classification_report
)

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks

# ---------------- Config ----------------
CSV_PATH   = "pr_reduced_data.csv"
FEATURES   = ['pm2_5', 'pm10', 'nh3', 'o3', 'so2']
TARGET     = 'aqi'
N_STEPS    = 7
THRESHOLD  = 0.5
EPOCHS     = 20
BATCH_SIZE = 32
VAL_SPLIT  = 0.2
PATIENCE   = 10

# -------------- Data load & scale --------------
df = pd.read_csv(CSV_PATH)

scaler = MinMaxScaler()
df_scaled = pd.DataFrame(
    scaler.fit_transform(df[FEATURES + [TARGET]]),
    columns=FEATURES + [TARGET]
)

def create_sequences(data, n_steps):
    X, y = [], []
    for i in range(len(data) - n_steps):
        X.append(data[i:i+n_steps, :-1])
        y.append(data[i+n_steps, -1])
    return np.array(X), np.array(y)

X, y = create_sequences(df_scaled.values, N_STEPS)

# Train-test split (time-ordered, like your code)
train_size = int(0.8 * len(X))
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

n_features = X.shape[2]
d_model    = 64
num_heads  = 4
d_ff       = 128
dropout    = 0.1
num_layers = 2

# -------------- Positional embedding --------------
class PositionalEmbedding(layers.Layer):
    def __init__(self, maxlen, d_model):
        super().__init__()
        self.pos_emb = self.add_weight(
            name="pos_emb", shape=(1, maxlen, d_model),
            initializer="random_normal", trainable=True
        )
    def call(self, x):
        # x: (batch, time, d_model)
        return x + self.pos_emb[:, :tf.shape(x)[1], :]

# -------------- Transformer block --------------
def transformer_block(x, d_model, num_heads, d_ff, dropout):
    # Multi-Head Self Attention
    attn_out = layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model//num_heads)(x, x)
    x = layers.Add()([x, layers.Dropout(dropout)(attn_out)])
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    # Feed Forward
    ffn = models.Sequential([
        layers.Dense(d_ff, activation="gelu"),
        layers.Dense(d_model),
    ])
    ffn_out = ffn(x)
    x = layers.Add()([x, layers.Dropout(dropout)(ffn_out)])
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    return x

# -------------- Build model --------------
inp = layers.Input(shape=(N_STEPS, n_features))
# Project per-timestep feature vector to d_model
x = layers.Dense(d_model)(inp)
# Add learnable positional embedding
x = PositionalEmbedding(N_STEPS, d_model)(x)
# Stack Transformer encoder layers
for _ in range(num_layers):
    x = transformer_block(x, d_model, num_heads, d_ff, dropout)
# Pool over time
x = layers.GlobalAveragePooling1D()(x)
x = layers.Dropout(dropout)(x)
out = layers.Dense(1)(x)  # regression to normalized AQI

model = models.Model(inp, out, name="AQI_Transformer")
model.compile(optimizer="adam", loss="mse", metrics=["mae"])
model.summary()

early_stop = callbacks.EarlyStopping(monitor="val_loss", patience=PATIENCE, restore_best_weights=True)

# -------------- Train --------------
history = model.fit(
    X_train, y_train,
    epochs=10,
    batch_size=BATCH_SIZE,
    validation_split=VAL_SPLIT,
    callbacks=[early_stop],
    verbose=1
)

# -------------- Plot: training history (loss) --------------
plt.figure(figsize=(10, 5))
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.xlabel("Epochs"); plt.ylabel("MSE"); plt.title("Transformer Training History (Loss)")
plt.legend(); plt.grid(True)
plt.show()

# -------------- Predict & inverse-transform to original scale --------------
y_pred = model.predict(X_test).flatten()

# prepare arrays for inverse scaling (target is last column)
def inverse_target_only(scaled_target):
    z = np.zeros((len(scaled_target), len(FEATURES) + 1))
    z[:, -1] = scaled_target
    return scaler.inverse_transform(z)[:, -1]

y_test_orig = inverse_target_only(y_test)
y_pred_orig = inverse_target_only(y_pred)

# -------------- Regression metrics --------------
mse  = mean_squared_error(y_test_orig, y_pred_orig)
rmse = np.sqrt(mse)
mae  = mean_absolute_error(y_test_orig, y_pred_orig)
r2   = r2_score(y_test_orig, y_pred_orig)

print("\n--- Transformer Regression Metrics ---")
print(f"MAE:  {mae:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"R^2:  {r2:.4f}")

# -------------- Classification metrics (threshold on ORIGINAL scale) --------------
y_test_cls = (y_test_orig > THRESHOLD).astype(int)
y_pred_cls = (y_pred_orig > THRESHOLD).astype(int)

acc  = accuracy_score(y_test_cls, y_pred_cls)
prec = precision_score(y_test_cls, y_pred_cls, zero_division=0)
rec  = recall_score(y_test_cls, y_pred_cls, zero_division=0)

print("\n--- Transformer Classification Metrics ---")
print(f"Accuracy:  {acc*100:.2f}%")
print(f"Precision: {prec:.4f}")
print(f"Recall:    {rec:.4f}")

# Confusion matrix
cm = confusion_matrix(y_test_cls, y_pred_cls)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=["Pred Safe", "Pred Harm"],
            yticklabels=["Actual Safe", "Actual Harm"])
plt.xlabel("Predicted"); plt.ylabel("Actual"); plt.title("Confusion Matrix for Transformer (Ranking based Features)")
plt.show()

# -------------- Cumulative Gain Curve --------------
# Use predicted AQI as a risk score (higher AQI => more likely 'harmful')
order = np.argsort(-y_pred_orig)  # descending by predicted AQI
y_true_sorted = y_test_cls[order]
cum_positives = np.cumsum(y_true_sorted == 1)
total_positives = (y_test_cls == 1).sum()
n = len(y_true_sorted)
perc_samples = np.arange(1, n+1) / n
gain = cum_positives / max(total_positives, 1)

plt.figure(figsize=(8, 6))
plt.plot(perc_samples, gain, label="Model")
plt.plot(perc_samples, perc_samples, label="Baseline")
plt.xlabel("Percentage of Samples")
plt.ylabel("Percentage of Positives Captured")
plt.title("Cumulative Gain Curve (Transformer)")
plt.legend(); plt.grid(True)
plt.show()

# -------------- Actual vs Predicted plot --------------
plt.figure(figsize=(12, 5))
plt.plot(y_test_orig, label="Actual AQI")
plt.plot(y_pred_orig, label="Predicted AQI", linestyle="--")
plt.xlabel("Time Steps"); plt.ylabel("AQI")
plt.title("Actual vs Predicted AQI (Transformer)")
plt.legend(); plt.grid(True)
plt.show()
# Out:
# Model: "AQI_Transformer"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_16      │ (None, 7, 5)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_28 (Dense)    │ (None, 7, 64)     │        384 │ input_layer_16[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ positional_embeddi… │ (None, 7, 64)     │        448 │ dense_28[0][0]    │
# │ (PositionalEmbeddi… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 7, 64)     │     16,640 │ positional_embed… │
# │ (MultiHeadAttentio… │                   │            │ positional_embed… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_37          │ (None, 7, 64)     │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 7, 64)     │          0 │ positional_embed… │
# │                     │                   │            │ dropout_37[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 7, 64)     │        128 │ add_16[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_12       │ (None, 7, 64)     │     16,576 │ layer_normalizat… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_38          │ (None, 7, 64)     │          0 │ sequential_12[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_17 (Add)        │ (None, 7, 64)     │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_38[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 7, 64)     │        128 │ add_17[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 7, 64)     │     16,640 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_40          │ (None, 7, 64)     │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_18 (Add)        │ (None, 7, 64)     │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_40[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 7, 64)     │        128 │ add_18[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_13       │ (None, 7, 64)     │     16,576 │ layer_normalizat… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_41          │ (None, 7, 64)     │          0 │ sequential_13[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_19 (Add)        │ (None, 7, 64)     │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_41[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 7, 64)     │        128 │ add_19[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ layer_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_42          │ (None, 64)        │          0 │ global_average_p… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_33 (Dense)    │ (None, 1)         │         65 │ dropout_42[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 67,841 (265.00 KB)
#  Trainable params: 67,841 (265.00 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 20s 26ms/step - loss: 0.1645 - mae: 0.2936 - val_loss: 0.0589 - val_mae: 0.1851
# Epoch 2/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - loss: 0.0545 - mae: 0.1781 - val_loss: 0.0306 - val_mae: 0.1123
# Epoch 3/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - loss: 0.0489 - mae: 0.1631 - val_loss: 0.0332 - val_mae: 0.1154
# Epoch 4/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 20s 26ms/step - loss: 0.0474 - mae: 0.1596 - val_loss: 0.0321 - val_mae: 0.1388
# Epoch 5/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 21s 28ms/step - loss: 0.0444 - mae: 0.1545 - val_loss: 0.0289 - val_mae: 0.1096
# Epoch 6/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 20s 26ms/step - loss: 0.0426 - mae: 0.1502 - val_loss: 0.0278 - val_mae: 0.1039
# Epoch 7/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 21s 27ms/step - loss: 0.0428 - mae: 0.1502 - val_loss: 0.0399 - val_mae: 0.1349
# Epoch 8/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 20s 27ms/step - loss: 0.0422 - mae: 0.1481 - val_loss: 0.0306 - val_mae: 0.1094
# Epoch 9/10
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 13s 27ms/step - loss: 0.0406 - mae: 0.1461 - val_loss: 0.0300 - val_mae: 0.1082
# Epoch 10/10
